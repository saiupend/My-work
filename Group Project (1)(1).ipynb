# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
hybrid_ds = pd.read_excel("C:/Users/gopik/OneDrive/Desktop/Hybrid.xlsx",header=0, nrows=10000)

# %%
fuel_ds = pd.read_excel("C:/Users/gopik/OneDrive/Desktop/Fuel.xlsx",header=0, nrows=10000)

# %%
hybrid_ds
# Out:
#               Year                                               Make  \
# 0             2012                                          Chevrolet
# 1             2013                                          Chevrolet
# 2             2013                                               Ford
# 3             2013                                               Ford
# 4             2013                                             Toyota
# ..             ...                                                ...
# 233          Range  the estimated driving distance (in kilometres)...
# 234  Recharge time  the estimated time (in hours) to fully recharg...
# 235  CO2 emissions  The vehicle's tailpipe emissions of carbon dio...
# 236     CO2 rating  the tailpipe emissions of carbon dioxide rated...
# 237    Smog rating  the tailpipe emissions of smog-forming polluta...
#
#                     Model Vehicle Class  Motor  Engine Size(L)  Cylinders  \
# ...

# %%
fuel_ds
# Out:
#                  Year                                               Make  \
# 0                2022                                              Acura
# 1                2022                                              Acura
# 2                2022                                              Acura
# 3                2022                                              Acura
# 4                2022                                              Acura
# ..                ...                                                ...
# 973               NaN                                    N = natural gas
# 974  Fuel consumption  City and highway fuel consumption ratings are ...
# 975     CO2 emissions  the tailpipe emissions of carbon dioxide (in g...
# 976        CO2 rating  the tailpipe emissions of carbon dioxide rated...
# 977       Smog rating  the tailpipe emissions of smog-forming polluta...
#
#                  Model Vehicle Class  Engine Size Litres  Cylinders  \
# ...

# %%
hybrid_ds.head()
# Out:
#    Year       Make                 Model Vehicle Class  Motor  Engine Size(L)  \
# 0  2012  Chevrolet                  Volt       Compact  111.0             1.4
# 1  2013  Chevrolet                  Volt       Compact  111.0             1.4
# 2  2013       Ford          C-MAX Energi      Mid-size   35.0             2.0
# 3  2013       Ford         Fusion Energi      Mid-size   35.0             2.0
# 4  2013     Toyota  Prius Plug-in Hybrid      Mid-size   60.0             1.8
#
#    Cylinders Transmission Primary Fuel                      Consumption  \
# 0        4.0           AV            B            2.5 (22.3 kWh/100 km)
# 1        4.0           AV            B            2.4 (21.4 kWh/100 km)
# 2        4.0           AV          B/X  2.7 ([23.2 kWh + 0.1 L]/100 km)
# 3        4.0           AV          B/X  2.7 ([23.2 kWh + 0.1 L]/100 km)
# 4        4.0           AV          B/X  2.5 ([18.0 kWh + 0.4 L]/100 km)
#
# ...

# %%
fuel_ds.head()
# Out:
#    Year   Make              Model Vehicle Class  Engine Size Litres  \
# 0  2022  Acura                ILX       Compact                 2.4
# 1  2022  Acura         MDX SH-AWD    SUV: Small                 3.5
# 2  2022  Acura         RDX SH-AWD    SUV: Small                 2.0
# 3  2022  Acura  RDX SH-AWD A-SPEC    SUV: Small                 2.0
# 4  2022  Acura         TLX SH-AWD       Compact                 2.0
#
#    Cylinders Transmission Type  City Consumption  Hwy Consumption  \
# 0        4.0          AM8    Z               9.9              7.0
# 1        6.0         AS10    Z              12.6              9.4
# 2        4.0         AS10    Z              11.0              8.6
# 3        4.0         AS10    Z              11.3              9.1
# 4        4.0         AS10    Z              11.2              8.0
#
#    Comb KM per ltr  Comb mpg  CO2 Emmissions  CO2 Rating  Smog Rating
# 0              8.6      33.0           200.0         6.0          3.0
# ...

# %%
fuel_ds.isna().sum()
# Out:
# Year                  15
# Make                   2
# Model                 23
# Vehicle Class         23
# Engine Size Litres    23
# Cylinders             23
# Transmission          23
# Type                  23
# City Consumption      23
# Hwy Consumption       23
# Comb KM per ltr       23
# Comb mpg              23
# CO2 Emmissions        23
# CO2 Rating            23
# Smog Rating           23
# dtype: int64

# %%
hybrid_ds.isna().sum()
# Out:
# Year                 9
# Make                 6
# Model               21
# Vehicle Class       21
# Motor               21
# Engine Size(L)      21
# Cylinders           21
# Transmission        21
# Primary Fuel        21
# Consumption         21
# battery range       21
# Recharge Time       21
# Secondary Fuel      21
# City Consumption    21
# Hwy Consumption     21
# Comb                21
# Fuel range          21
# CO2 emmissions      21
# CO2 Rating          41
# Smog Rating         57
# dtype: int64

# %%
hybrid_ds.shape
# Out:
# (238, 20)

# %%
fuel_ds.shape
# Out:
# (978, 15)

# %%
hybrid_ds['Year'] = hybrid_ds['Year'].fillna(2021)

# %%
fuel_ds['Year'] = fuel_ds['Year'].fillna(2021)

# %%
hybrid_ds['Model'] = hybrid_ds['Model'].fillna('EX')

# %%
hybrid_ds['Vehicle Class'] = hybrid_ds['Vehicle Class'].fillna('SUV')
hybrid_ds['Engine Size(L)'] = hybrid_ds['Engine Size(L)'].fillna(3)
hybrid_ds['Motor'] = hybrid_ds['Motor'].fillna(100)
hybrid_ds['Cylinders'] = hybrid_ds['Cylinders'].fillna(6)
hybrid_ds['Transmission'] = hybrid_ds['Transmission'].fillna('AMT')
hybrid_ds['Primary Fuel'] = hybrid_ds['Primary Fuel'].fillna('B/X')
hybrid_ds['Consumption'] = hybrid_ds['Consumption'].fillna(2.9)

# %%
hybrid_ds['City Consumption'] = hybrid_ds['City Consumption'].fillna(7.5)

# %%
hybrid_ds['Hwy Consumption'] = hybrid_ds['Hwy Consumption'].fillna(11.5)

# %%
hybrid_ds['battery range'] = hybrid_ds['battery range'].fillna(75)

# %%
hybrid_ds['Recharge Time'] = hybrid_ds['Recharge Time'].fillna(6)

# %%
hybrid_ds['Secondary Fuel'] = hybrid_ds['Secondary Fuel'].fillna('X')

# %%
hybrid_ds['Comb'] = hybrid_ds['Comb'].fillna(9.1)

# %%
hybrid_ds['Fuel range'] = hybrid_ds['Fuel range'].fillna(715)

# %%
hybrid_ds['CO2 emmissions'] = hybrid_ds['CO2 emmissions'].fillna(52)

# %%
hybrid_ds['CO2 Rating'] = hybrid_ds['CO2 Rating'].fillna(61)

# %%
hybrid_ds['Smog Rating'] = hybrid_ds['Smog Rating'].fillna(7)

# %%
hybrid_ds.isna().sum()
# Out:
# Year                0
# Make                6
# Model               0
# Vehicle Class       0
# Motor               0
# Engine Size(L)      0
# Cylinders           0
# Transmission        0
# Primary Fuel        0
# Consumption         0
# battery range       0
# Recharge Time       0
# Secondary Fuel      0
# City Consumption    0
# Hwy Consumption     0
# Comb                0
# Fuel range          0
# CO2 emmissions      0
# CO2 Rating          0
# Smog Rating         0
# dtype: int64

# %%
hybrid_ds['Make'] = hybrid_ds['Make'].fillna('BMW')

# %%
hybrid_ds.isna().sum()
# Out:
# Year                0
# Make                0
# Model               0
# Vehicle Class       0
# Motor               0
# Engine Size(L)      0
# Cylinders           0
# Transmission        0
# Primary Fuel        0
# Consumption         0
# battery range       0
# Recharge Time       0
# Secondary Fuel      0
# City Consumption    0
# Hwy Consumption     0
# Comb                0
# Fuel range          0
# CO2 emmissions      0
# CO2 Rating          0
# Smog Rating         0
# dtype: int64

# %%
fuel_ds['Vehicle Class'] = fuel_ds['Vehicle Class'].fillna('SUV')

# %%
fuel_ds['Engine Size Litres'] = fuel_ds['Engine Size Litres'].fillna(3)

# %%
fuel_ds['Cylinders'] = fuel_ds['Cylinders'].fillna(6)
fuel_ds['Transmission'] = fuel_ds['Transmission'].fillna('AMT')

# %%
fuel_ds['Type'] = fuel_ds['Type'].fillna('X')
fuel_ds['City Consumption'] = fuel_ds['City Consumption'].fillna(7.5)

# %%
fuel_ds['Hwy Consumption'] = fuel_ds['Hwy Consumption'].fillna(11.5)
fuel_ds['Comb KM per ltr'] = fuel_ds['Comb KM per ltr'].fillna(9.1)

# %%
fuel_ds['Comb mpg'] = fuel_ds['Comb mpg'].fillna(715)
fuel_ds['CO2 Emmissions'] = fuel_ds['CO2 Emmissions'].fillna(52)

# %%
fuel_ds['CO2 Rating'] = fuel_ds['CO2 Rating'].fillna(61)
fuel_ds['Smog Rating'] = fuel_ds['Smog Rating'].fillna(7)

# %%
fuel_ds['Model'] = fuel_ds['Model'].fillna('EX')
fuel_ds['Make'] = fuel_ds['Make'].fillna('BMW')

# %%
hybrid_ds.isna().sum()
# Out:
# Year                0
# Make                0
# Model               0
# Vehicle Class       0
# Motor               0
# Engine Size(L)      0
# Cylinders           0
# Transmission        0
# Primary Fuel        0
# Consumption         0
# battery range       0
# Recharge Time       0
# Secondary Fuel      0
# City Consumption    0
# Hwy Consumption     0
# Comb                0
# Fuel range          0
# CO2 emmissions      0
# CO2 Rating          0
# Smog Rating         0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.heatmap(hybrid_ds.corr(), annot =True, linewidths = 3);

# %%
sns.barplot(x='Cylinders',y='City Consumption',data=fuel_ds);

# %%
sns.barplot(x='Cylinders',y='City Consumption',data=hybrid_ds);

# %%
sns.barplot(x='CO2 Emmissions',y='City Consumption',data=fuel_ds);

# %%
sns.barplot(x='CO2 emmissions',y='City Consumption',data=hybrid_ds);
