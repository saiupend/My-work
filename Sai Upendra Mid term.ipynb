# %%
import seaborn as sns

# %%
passenger=sns.load_dataset("titanic")

# %%
passenger
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
passenger.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import pandas as pd

# %%
survived_data=pd.DataFrame(passenger.groupby('class')['survived'].sum())

# %%
survived_data
# Out:
#         survived
# class
# First        136
# Second        87
# Third        119

# %%
passenger.shape
# Out:
# (891, 15)

# %%
survived_data['survival%']=survived_data['survived']/891

# %%
survived_data
# Out:
#         survived  survival%
# class
# First        136   0.152637
# Second        87   0.097643
# Third        119   0.133558

# %%
sales=pd.read_csv('Zest Sales.csv')

# %%
sales
# Out:
#         Product Name Order Channel  Quantiy Sold  Unit Sale Price ($)  \
# 0            Tablets        Online             4                  2.0
# 1   Nokia Cellphones      In Store             2                400.0
# 2  Toshiba Batteries        Online            10                 10.0
# 3      Mountain Bike        Online             2                500.0
# 4  Greys Cutlery box        Online             1                100.0
# 5     Prince Biscuit      In Store           100                  2.0
# 6            Uni Pen      In Store           100                100.0
# 7        Atom Shirts      In Store             5                 55.0
# 8       Dasani Water        Online             4                  2.5
#
#    Unit Cost Price ($)
# 0                 0.49
# 1               150.00
# 2                 8.00
# 3               200.00
# 4                35.00
# 5                 1.34
# 6                44.00
# 7                15.00
# 8                 1.00

# %%
sales['total revenue']=sales['Quantiy Sold']*sales['Unit Sale Price ($)']

# %%
sales
# Out:
#         Product Name Order Channel  Quantiy Sold  Unit Sale Price ($)  \
# 0            Tablets        Online             4                  2.0
# 1   Nokia Cellphones      In Store             2                400.0
# 2  Toshiba Batteries        Online            10                 10.0
# 3      Mountain Bike        Online             2                500.0
# 4  Greys Cutlery box        Online             1                100.0
# 5     Prince Biscuit      In Store           100                  2.0
# 6            Uni Pen      In Store           100                100.0
# 7        Atom Shirts      In Store             5                 55.0
# 8       Dasani Water        Online             4                  2.5
#
#    Unit Cost Price ($)  total revenue
# 0                 0.49            8.0
# 1               150.00          800.0
# 2                 8.00          100.0
# 3               200.00         1000.0
# 4                35.00          100.0
# ...

# %%
sales['totalcost']=sales['Quantiy Sold']*sales['Unit Cost Price ($)']

# %%
sales['totalcost']
# Out:
# 0       1.96
# 1     300.00
# 2      80.00
# 3     400.00
# 4      35.00
# 5     134.00
# 6    4400.00
# 7      75.00
# 8       4.00
# Name: totalcost, dtype: float64

# %%
sales['totalprofit']=sales['total revenue']*sales['totalcost']

# %%
sales
# Out:
#         Product Name Order Channel  Quantiy Sold  Unit Sale Price ($)  \
# 0            Tablets        Online             4                  2.0
# 1   Nokia Cellphones      In Store             2                400.0
# 2  Toshiba Batteries        Online            10                 10.0
# 3      Mountain Bike        Online             2                500.0
# 4  Greys Cutlery box        Online             1                100.0
# 5     Prince Biscuit      In Store           100                  2.0
# 6            Uni Pen      In Store           100                100.0
# 7        Atom Shirts      In Store             5                 55.0
# 8       Dasani Water        Online             4                  2.5
#
#    Unit Cost Price ($)  total revenue  totalcost  totalprofit
# 0                 0.49            8.0       1.96        15.68
# 1               150.00          800.0     300.00    240000.00
# 2                 8.00          100.0      80.00      8000.00
# ...

# %%
sales.sort_values(by=['totalprofit'],ascending=False)
# Out:
#         Product Name Order Channel  Quantiy Sold  Unit Sale Price ($)  \
# 6            Uni Pen      In Store           100                100.0
# 3      Mountain Bike        Online             2                500.0
# 1   Nokia Cellphones      In Store             2                400.0
# 5     Prince Biscuit      In Store           100                  2.0
# 7        Atom Shirts      In Store             5                 55.0
# 2  Toshiba Batteries        Online            10                 10.0
# 4  Greys Cutlery box        Online             1                100.0
# 8       Dasani Water        Online             4                  2.5
# 0            Tablets        Online             4                  2.0
#
#    Unit Cost Price ($)  total revenue  totalcost  totalprofit
# 6                44.00        10000.0    4400.00  44000000.00
# 3               200.00         1000.0     400.00    400000.00
# 1               150.00          800.0     300.00    240000.00
# ...

# %%
#Uni Pen has the highest profit

# %%
sales.groupby('Order Channel')['total revenue'].sum()
# Out:
# Order Channel
# In Store    11275.0
# Online       1218.0
# Name: total revenue, dtype: float64

# %%
Fruits = ['apple', 'George' , 'banana', 'kiwi']
Fruits

for i in Fruits:
    if i!='George':
        print(i)
# Out:
# apple
# banana
# kiwi

# %%
tips_data = sns.load_dataset('tips')
pd.pivot_table(tips_data, values='tip', index='day',
columns='sex', aggfunc='mean')
# Out:
# sex       Male    Female
# day
# Thur  2.980333  2.575625
# Fri   2.693000  2.781111
# Sat   3.083898  2.801786
# Sun   3.220345  3.367222

# %%
tipspivot=pd.pivot_table(tips_data, values='tip', index='day',
columns='sex', aggfunc='mean')

# %%
sns.heatmap(tipspivot, annot=True,cmap="Blues", cbar = False)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='day'>

# %%
passenger.loc[(passenger['who'] == 'woman') & (passenger['survived'] == 0) & (passenger['class'] == 'Third')]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 18          0       3  female  31.0      1      0  18.0000        S  Third
# 38          0       3  female  18.0      2      0  18.0000        S  Third
# 40          0       3  female  40.0      1      0   9.4750        S  Third
# 49          0       3  female  18.0      1      0  17.8000        S  Third
# 71          0       3  female  16.0      5      2  46.9000        S  Third
# 100         0       3  female  28.0      0      0   7.8958        S  Third
# 113         0       3  female  20.0      1      0   9.8250        S  Third
# 114         0       3  female  17.0      0      0  14.4583        C  Third
# 132         0       3  female  47.0      1      0  14.5000        S  Third
# 140         0       3  female   NaN      0      2  15.2458        C  Third
# 167         0       3  female  45.0      1      4  27.9000        S  Third
# ...

# %%
tips_data['percentage'] = round((tips_data['tip']/tips_data['total_bill'])*100,2)

# %%
tips_data
# Out:
#      total_bill   tip     sex smoker   day    time  size  percentage
# 0         16.99  1.01  Female     No   Sun  Dinner     2        5.94
# 1         10.34  1.66    Male     No   Sun  Dinner     3       16.05
# 2         21.01  3.50    Male     No   Sun  Dinner     3       16.66
# 3         23.68  3.31    Male     No   Sun  Dinner     2       13.98
# 4         24.59  3.61  Female     No   Sun  Dinner     4       14.68
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       20.39
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        7.36
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        8.82
# 242       17.82  1.75    Male     No   Sat  Dinner     2        9.82
# 243       18.78  3.00  Female     No  Thur  Dinner     2       15.97
#
# [244 rows x 8 columns]

# %%
tips_data.sort_values(by=['percentage'])
# Out:
#      total_bill   tip     sex smoker  day    time  size  percentage
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2        3.56
# 102       44.30  2.50  Female    Yes  Sat  Dinner     3        5.64
# 57        26.41  1.50  Female     No  Sat  Dinner     2        5.68
# 0         16.99  1.01  Female     No  Sun  Dinner     2        5.94
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5        6.57
# ..          ...   ...     ...    ...  ...     ...   ...         ...
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4       28.05
# 232       11.61  3.39    Male     No  Sat  Dinner     2       29.20
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1       32.57
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2       41.67
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2       71.03
#
# [244 rows x 8 columns]

# %%
tips_data.sort_values(by=['percentage'],ascending=True)
# Out:
#      total_bill   tip     sex smoker  day    time  size  percentage
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2        3.56
# 102       44.30  2.50  Female    Yes  Sat  Dinner     3        5.64
# 57        26.41  1.50  Female     No  Sat  Dinner     2        5.68
# 0         16.99  1.01  Female     No  Sun  Dinner     2        5.94
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5        6.57
# ..          ...   ...     ...    ...  ...     ...   ...         ...
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4       28.05
# 232       11.61  3.39    Male     No  Sat  Dinner     2       29.20
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1       32.57
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2       41.67
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2       71.03
#
# [244 rows x 8 columns]

# %%
mpg=sns.load_dataset("mpg")

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mpg.groupby(['origin'])[['weight']].mean()
# Out:
#              weight
# origin
# europe  2423.300000
# japan   2221.227848
# usa     3361.931727

# %%
tips_data
# Out:
#      total_bill   tip     sex smoker   day    time  size  percentage  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2        5.94
# 1         10.34  1.66    Male     No   Sun  Dinner     3       16.05
# 2         21.01  3.50    Male     No   Sun  Dinner     3       16.66
# 3         23.68  3.31    Male     No   Sun  Dinner     2       13.98
# 4         24.59  3.61  Female     No   Sun  Dinner     4       14.68
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       20.39
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        7.36
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        8.82
# 242       17.82  1.75    Male     No   Sat  Dinner     2        9.82
# 243       18.78  3.00  Female     No  Thur  Dinner     2       15.97
#
#      food_bill
# 0        15.98
# 1         8.68
# 2        17.51
# 3        20.37
# 4        20.98
# ..         ...
# 239      23.11
# ...

# %%
tips_data[(tips_data['sex']=='Male') & (tips_data['smoker']=='Yes')]['total_bill'].median()
# Out:
# 20.39

# %%
tips_data[(tips_data['sex']=='Male') & (tips_data['smoker']=='Yes')]['total_bill'].mean()
# Out:
# 22.2845

# %%
flights=sns.load_dataset("flights")

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights.groupby('year')['passengers'].sum()
# Out:
# year
# 1949    1520
# 1950    1676
# 1951    2042
# 1952    2364
# 1953    2700
# 1954    2867
# 1955    3408
# 1956    3939
# 1957    4421
# 1958    4572
# 1959    5140
# 1960    5714
# Name: passengers, dtype: int64

# %%
passenger.groupby(['who','class'])['who'].count()
# Out:
# who    class
# child  First       6
#        Second     19
#        Third      58
# man    First     119
#        Second     99
#        Third     319
# woman  First      91
#        Second     66
#        Third     114
# Name: who, dtype: int64
